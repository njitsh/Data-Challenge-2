# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import glob
import os
from tqdm import tqdm
import numpy as np
from datetime import timedelta

# %% [markdown]
# ## Preprocess data functions

# %%
def getAllFiles(path, file_name_type, start_year, start_month, end_year, end_month, included_columns, msoa_dictionary):
    li = []

    for x in tqdm(list(os.walk(path))):

        all_files = glob.glob(x[0] + "/*" + file_name_type + ".csv")

        for file_path in all_files:
            if (inTimePeriod(file_path, start_year, start_month, end_year, end_month)):
                df = pd.read_csv(file_path, index_col=None, header=0, usecols=included_columns)
                df = df[df['LSOA name'].notna()]
                df['MSOA'] = df['LSOA name'].apply(LSOAtoMSOA)
                df['MSOA'] = df['MSOA'].map(msoa_dictionary)
                li.append(df)
                
    complete_df = pd.concat(li, axis=0, ignore_index=True)
    complete_df.rename_axis('index')

    return complete_df

def inTimePeriod(file_path, start_year, start_month, end_year, end_month):
    file_path_parts = file_path.split("\\")
    file_name = file_path_parts[len(file_path_parts) - 1]
    year = int(file_name[:4])
    month = int(file_name[5:7])
    start_bool = (year >= start_year) or (year == start_year and month >= start_month)
    end_bool = (year <= end_year) or (year == end_year and month <= end_month)
    if (start_bool and end_bool):
        return True
    return False

def LSOAtoMSOA(LSOA):
    return LSOA[:-1]

def countMSOA(df):
    df = df.groupby(['Month', 'MSOA', 'Crime type'])
    df = df.agg(count=('LSOA name', 'count')).unstack(fill_value=0).stack()
    df = df.reset_index()
    return df

# %% [markdown]
# ## MSOA Names table

# %%
msoa_names = pd.read_csv("MSOA-Names.csv", header=0, usecols=["msoa11nm", "msoa11hclnm"])
msoa_dict = dict(zip(msoa_names.msoa11nm, msoa_names.msoa11hclnm))
msoa_dict
# Out:
# {'Adur 001': 'Hillside',
#  'Adur 002': 'Buckingham',
#  'Adur 003': 'North Lancing',
#  'Adur 004': 'Kingston & Southwick',
#  'Adur 005': 'Shoreham Central & Beach',
#  'Adur 006': 'Cokeham & Sompting',
#  'Adur 007': 'Marsh Barn & Widewater',
#  'Adur 008': 'South Lancing',
#  'Allerdale 001': 'Wigton & Silloth',
#  'Allerdale 002': 'Boltons, Warnell & Solway Coast',
#  'Allerdale 003': 'Aspatria & Abbeytown',
#  'Allerdale 004': 'Maryport, Dearham & Crosby',
#  'Allerdale 005': 'Flimby, Ellenborough & Broughton Moor',
#  'Allerdale 006': 'West Cockermouth & Great Broughton',
#  'Allerdale 007': 'East Cockermouth & Buttermere',
#  'Allerdale 008': 'Workington North & Seaton',
#  'Allerdale 009': 'Workington West',
#  'Allerdale 010': 'Workington East',
#  'Allerdale 011': 'Harrington, Stainburn & Great Clifton',
#  'Allerdale 012': 'Keswick & Derwent Valley',
#  'Amber Valley 001': 'Alfreton',
#  'Amber Valley 002': 'Crich, Holloway & Wingfield',
#  'Amber Valley 003': 'Somercotes & Pye Bridge',
#  'Amber Valley 004': 'Swanwick & Leabrooks',
#  'Amber Valley 005': 'Ripley East, Riddings & Ironville',
#  'Amber Valley 006': 'Ripley West',
#  'Amber Valley 007': 'Ambergate, Heage & Idridgehay',
#  'Amber Valley 008': 'Ripley South & Loscoe',
#  'Amber Valley 009': 'Belper Far Laund',
#  'Amber Valley 010': 'Belper Town',
#  'Amber Valley 011': 'Openwoodgate & Holbrook',
#  'Amber Valley 012': 'Heanor Gate & Aldercar',
#  'Amber Valley 013': 'Heanor East & Langley Mill',
#  'Amber Valley 015': 'Kilburn & Horsley',
#  'Amber Valley 016': 'Duffield, Quarndon & Kirk Langley',
#  'Amber Valley 017': 'Heanor South & Shipley Park',
#  'Arun 001': 'Arundel',
#  'Arun 002': 'Angmering North, Patching & Findon',
#  'Arun 003': 'Westergate, Eastergate & Walberton',
#  'Arun 004': 'Wick & Toddington',
#  'Arun 005': 'Angmering South',
#  'Arun 006': 'Yapton & Climping',
#  'Arun 007': 'Rustington North',
#  'Arun 008': 'Ferring & Kingston Gorse',
#  'Arun 009': 'Littlehampton East',
#  'Arun 010': 'East Preston & Rustington East',
#  'Arun 011': 'Littlehampton West and River',
#  'Arun 012': 'North Bersted',
#  'Arun 013': 'Middleton-on-Sea',
#  'Arun 014': 'South Bersted',
#  'Arun 015': 'Felpham',
#  'Arun 016': 'Hawthorn Road',
#  'Arun 017': 'Bognor Regis Central',
#  'Arun 018': 'Aldwick',
#  'Arun 019': 'Nyetimber & Pagham',
#  'Ashfield 001': 'Stanton Hill & Skegby',
#  'Ashfield 002': 'The Dales & South Skegby',
#  'Ashfield 003': 'Huthwaite',
#  'Ashfield 004': 'Sutton Forest Side & New Cross',
#  'Ashfield 005': 'Sutton Central & Leamington',
#  'Ashfield 006': "Sutton St Mary's & Ashfields",
#  'Ashfield 007': 'East Kirkby',
#  'Ashfield 008': 'Kirkby Central',
#  'Ashfield 009': 'Kirkby Larwood & Kingsway',
#  'Ashfield 010': 'Annesley & Kirkby Woodhouse',
#  'Ashfield 011': 'Selston',
#  'Ashfield 012': 'Jacksdale & Underwood',
#  'Ashfield 013': 'Hucknall North & East',
#  'Ashfield 014': 'Hucknall Town',
#  'Ashfield 015': 'West Hucknall',
#  'Ashfield 016': 'Hucknall Westville',
#  'Ashford 001': 'Wye, Chilham & Kennington',
#  'Ashford 002': 'Charing, Pluckley & Challock',
#  'Ashford 003': 'Kennington & Little Burton Farm',
#  'Ashford 004': 'Bybrook, Orchard Park & Godinton',
#  'Ashford 005': 'Ashford Central',
#  'Ashford 006': 'Highfield & Willesborough',
#  'Ashford 007': 'Beaver & Singleton',
#  'Ashford 008': 'Washford & Stanhope',
#  'Ashford 009': 'Park Farm',
#  'Ashford 010': 'Brabourne Lees & North Romney',
#  'Ashford 011': 'Biddenden, Smarden & High Halden',
#  'Ashford 012': 'Great Chart, Bethersden & Woodchurch',
#  'Ashford 013': 'Tenterden & Rolvenden',
#  'Ashford 014': 'Hamstreet & Isle of Oxney',
#  'Aylesbury Vale 001': 'Buckingham South, Maids Moreton & Akeley',
#  'Aylesbury Vale 002': 'Buckingham North',
#  'Aylesbury Vale 003': 'Newton Longville & Great Horwood',
#  'Aylesbury Vale 004': 'Marsh Gibbon, Steeple Claydon & Tingewick',
#  'Aylesbury Vale 005': 'Winslow & Padbury',
#  'Aylesbury Vale 006': 'Granborough, Stewkley & Great Brickhill',
#  'Aylesbury Vale 007': 'Wing, Wingrave & Bierton',
#  'Aylesbury Vale 008': 'Waddesdon & Whitchurch',
#  'Aylesbury Vale 009': 'Cheddington, Pitstone & Edlesborough',
#  'Aylesbury Vale 010': 'Oakley, Brill & Edgcott',
#  'Aylesbury Vale 011': 'Watermead & Elmhurst',
#  'Aylesbury Vale 012': 'Berryfields & Haydon Hill',
#  'Aylesbury Vale 013': 'Gatehouse',
#  'Aylesbury Vale 014': 'Victoria Park',
#  'Aylesbury Vale 015': 'Aylesbury Central',
#  'Aylesbury Vale 016': 'Fairford Leys',
#  'Aylesbury Vale 017': 'Bedgrove & Walton',
#  'Aylesbury Vale 018': 'California & Southcourt',
#  'Aylesbury Vale 019': 'Mandeville & Elm Farm',
#  'Aylesbury Vale 020': 'Walton Court & Hawkslade',
#  'Aylesbury Vale 021': 'Stoke Mandeville & Aston Clinton',
#  'Aylesbury Vale 022': 'Haddenham, Dinton & Stone',
#  'Aylesbury Vale 023': 'Worminghall, Long Crendon & Cuddington',
#  'Aylesbury Vale 024': 'Wendover',
#  'Babergh 001': 'Lavenham, Bildeston & Brettenham',
#  'Babergh 002': 'Glemsford & Lawshall',
#  'Babergh 003': 'North Sudbury & Long Melford',
#  'Babergh 004': 'Hadleigh',
#  'Babergh 005': 'Sproughton, Washbrook & Hintlesham',
#  'Babergh 006': 'Acton, Great Waldingfield & Bures',
#  'Babergh 007': 'Sudbury',
#  'Babergh 008': 'Great Cornard',
#  'Babergh 009': 'Leavenheath, Nayland & Boxford',
#  'Babergh 010': 'East Bergholt, Brantham & Capel St Mary',
#  'Babergh 011': 'Shotley Peninsula',
#  'Barking and Dagenham 001': 'Marks Gate',
#  'Barking and Dagenham 002': 'Chadwell Heath East',
#  'Barking and Dagenham 003': 'Eastbrookend',
#  'Barking and Dagenham 004': 'Becontree Heath',
#  'Barking and Dagenham 006': 'Central Park & Frizlands Lane',
#  'Barking and Dagenham 007': 'Becontree East',
#  'Barking and Dagenham 008': 'Becontree West',
#  'Barking and Dagenham 009': 'Dagenham North',
#  'Barking and Dagenham 010': 'Dagenham Eastbrook',
#  'Barking and Dagenham 011': 'Longbridge & Barking Park',
#  'Barking and Dagenham 012': 'Becontree South',
#  'Barking and Dagenham 013': 'Dagenham Central',
#  'Barking and Dagenham 014': 'Old Dagenham Park & Village',
#  'Barking and Dagenham 015': 'Barking Central',
#  'Barking and Dagenham 016': 'Barking East',
#  'Barking and Dagenham 017': 'Mayesbrook Park & Rippleside',
#  'Barking and Dagenham 018': 'Goresbrook & Scrattons Farm',
#  'Barking and Dagenham 019': 'Creekmouth & Barking Riverside',
#  'Barking and Dagenham 020': 'Rylands Estate & Dagenham Dock',
#  'Barking and Dagenham 021': 'Gascoigne Estate & Roding Riverside',
#  'Barking and Dagenham 022': 'Thames View',
#  'Barking and Dagenham 023': 'Becontree North',
#  'Barnet 001': 'High Barnet & Hadley',
#  'Barnet 002': 'Hadley Wood',
#  'Barnet 003': 'Oak Hill',
#  'Barnet 004': 'Ducks Island & Underhill',
#  'Barnet 005': 'New Barnet West',
#  'Barnet 006': 'New Barnet Town & East Barnet',
#  'Barnet 007': 'Totteridge & Barnet Gate',
#  'Barnet 008': 'Oakleigh Park',
#  'Barnet 009': 'Osidge',
#  'Barnet 010': 'Brunswick Park Road',
#  'Barnet 011': 'Whetstone East',
#  'Barnet 012': 'Woodside Park',
#  'Barnet 013': 'Edgware East',
#  'Barnet 014': 'Edgware Park',
#  'Barnet 015': 'Friern Barnet',
#  'Barnet 016': 'Mill Hill Park',
#  'Barnet 017': 'Mill Hill East',
#  'Barnet 018': 'Edgware Central',
#  'Barnet 019': 'North Finchley',
#  'Barnet 020': 'West Finchley',
#  'Barnet 021': 'Mill Hill Broadway',
#  'Barnet 022': 'Colney Hatch',
#  'Barnet 023': 'Church End',
#  'Barnet 024': 'Burnt Oak & Watling Park',
#  'Barnet 025': 'Copthall & Downage',
#  'Barnet 026': 'Grahame Park',
#  'Barnet 027': 'Fallow Corner',
#  'Barnet 028': 'Finchley Central',
#  'Barnet 029': 'East Finchley',
#  'Barnet 030': 'Colindale',
#  'Barnet 031': 'North Hendon & Sunny Hill',
#  'Barnet 032': 'Hendon Central',
#  'Barnet 033': 'Hampstead Garden Suburb',
#  'Barnet 034': 'Hendon Park',
#  'Barnet 035': 'Temple Fortune',
#  'Barnet 036': 'West Hendon',
#  'Barnet 037': 'Golders Green North',
#  'Barnet 038': 'Golders Green South',
#  'Barnet 039': 'Brent Cross & Staples Corner',
#  'Barnet 040': 'North Cricklewood',
#  'Barnet 041': 'Childs Hill',
#  'Barnsley 001': 'Royston West',
#  'Barnsley 002': 'Royston East & Carlton',
#  'Barnsley 003': 'Shafton & Upper Cudworth',
#  'Barnsley 004': 'Mapplewell & Staincross',
#  'Barnsley 005': 'Darton & Kexborough',
#  'Barnsley 006': 'Grimethorpe & Brierley',
#  'Barnsley 007': 'Athersley',
#  'Barnsley 008': 'Cudworth Village',
#  'Barnsley 009': 'Monk Bretton',
#  'Barnsley 010': 'Honeywell',
#  'Barnsley 011': 'Lundwood',
#  'Barnsley 012': 'Wilthorpe & Barugh Green',
#  'Barnsley 013': 'Barnsley Town & Park Road',
#  'Barnsley 014': 'Thurnscoe',
#  'Barnsley 015': 'Ardsley & Stairfoot',
#  'Barnsley 016': 'Silkstone, Hoylandswaine & Cawthorne',
#  'Barnsley 017': 'Worsbrough Common',
#  'Barnsley 018': 'Kendray',
#  'Barnsley 019': 'Dodworth',
#  'Barnsley 020': 'Darfield & Great Houghton',
#  'Barnsley 021': 'Worsbrough',
#  'Barnsley 022': 'Goldthorpe',
#  'Barnsley 023': 'Wombwell North',
#  'Barnsley 024': 'Penistone',
#  'Barnsley 025': 'Bolton-upon-Dearne',
#  'Barnsley 026': 'Wombwell South',
#  'Barnsley 027': 'Ingbirchworth, Dunford Bridge & Thurgoland',
#  'Barnsley 028': 'Birdwell',
#  'Barnsley 029': 'Elsecar',
#  'Barnsley 030': 'Hoyland',
#  'Barrow-in-Furness 001': 'Askam & Dalton North',
#  'Barrow-in-Furness 002': 'Dalton South',
#  'Barrow-in-Furness 003': 'Hawcoat & Furness Abbey',
#  'Barrow-in-Furness 004': 'Orsmgill & Hindpool',
#  'Barrow-in-Furness 005': 'Parkside',
#  'Barrow-in-Furness 006': 'Roose',
#  'Barrow-in-Furness 007': 'Abbotsmead & Salthouse',
#  'Barrow-in-Furness 008': 'Barrow Central',
#  'Barrow-in-Furness 009': 'Walney Island North',
#  'Barrow-in-Furness 010': 'Walney Island South & Barrow Island',
#  'Basildon 001': 'Billericay North East',
#  'Basildon 002': "Billericay Queen's Park",
#  'Basildon 003': 'Billericay Central & Sunnymede',
#  'Basildon 004': 'Billericay Tye Common',
#  'Basildon 005': 'Wickford North East',
#  'Basildon 006': 'Wickford West',
#  'Basildon 007': 'Wickford Shotgate',
#  'Basildon 008': 'Wickford South',
#  'Basildon 009': 'Bursteads',
#  'Basildon 010': 'Steeple View & Noak Bridge',
#  'Basildon 011': 'Felmore & Bowers Gifford',
#  'Basildon 012': 'Whitmore Way & Fremnells',
#  'Basildon 013': 'Chalvedon',
#  'Basildon 014': 'Laindon West & Southfields',
#  'Basildon 015': 'Basildon Central & Pipps Hill',
#  'Basildon 016': 'Laindon Central',
#  'Basildon 017': 'Laindon East & Lee Chapel North',
#  'Basildon 018': 'Eversley',
#  'Basildon 019': 'Barstable',
#  'Basildon 020': 'Lee Chapel South & Kingswood',
#  'Basildon 021': 'Langdon Hills',
#  'Basildon 022': 'Vange & Pitsea',
#  'Basingstoke and Deane 001': 'Tadley West',
#  'Basingstoke and Deane 002': 'Tadley East, Pamber & Silchester',
#  'Basingstoke and Deane 003': 'Woolton Hill, Burghclere & Bishops Green',
#  'Basingstoke and Deane 004': 'Kingsclere & Heath End',
#  'Basingstoke and Deane 005': 'Bramley, Sherfield & the Sherbornes',
#  'Basingstoke and Deane 006': 'Chineham',
#  'Basingstoke and Deane 007': 'Popley',
#  'Basingstoke and Deane 008': 'Daneshill & Little Basing',
#  'Basingstoke and Deane 009': 'Houndmills & Oakridge',
#  'Basingstoke and Deane 010': 'Winklebury & Rooksdown',
#  'Basingstoke and Deane 011': 'Basingstoke Central, Black Dam & Eastrop',
#  'Basingstoke and Deane 012': 'Kings Furlong',
#  'Basingstoke and Deane 013': 'Buckskin & Worting',
#  'Basingstoke and Deane 014': 'South Ham & West Ham',
#  'Basingstoke and Deane 015': 'East Oakley',
#  'Basingstoke and Deane 016': 'Viables',
#  'Basingstoke and Deane 017': 'Old Basing & the Candovers',
#  'Basingstoke and Deane 018': 'Kempshott',
#  'Basingstoke and Deane 019': 'Brighton Hill',
#  'Basingstoke and Deane 020': 'Whitchurch & Ashmansworth',
#  'Basingstoke and Deane 021': 'Hatch Warren',
#  'Basingstoke and Deane 022': 'Overton & North Waltham',
#  'Bassetlaw 001': 'Harworth, Bircotes & Blyth',
#  'Bassetlaw 002': 'Clarborough, Beckingham & Misterton',
#  'Bassetlaw 003': 'Ranskill, Everton & Gringley',
#  'Bassetlaw 004': 'Carlton & Langold',
#  'Bassetlaw 005': 'Retford North',
#  'Bassetlaw 006': 'Worksop North',
#  'Bassetlaw 008': 'Retford East',
#  'Bassetlaw 009': 'Worksop West, Shireoaks & Rhodesia',
#  'Bassetlaw 010': 'Retford South',
#  'Bassetlaw 012': 'Worksop Cheapside',
#  'Bassetlaw 013': 'Worksop Town & South',
#  'Bassetlaw 014': 'Manton, Clumber & Elkesley',
#  'Bassetlaw 015': 'Tuxford, Markham & Rampton',
#  'Bassetlaw 016': 'Worksop Kilton',
#  'Bath and North East Somerset 001': 'Keynsham North',
#  'Bath and North East Somerset 002': 'Keynsham South',
#  'Bath and North East Somerset 003': 'Keynsham East',
#  'Bath and North East Somerset 004': 'Lambridge & Fairfield Park',
#  'Bath and North East Somerset 005': 'Weston',
#  'Bath and North East Somerset 006': 'Walcot',
#  'Bath and North East Somerset 007': 'Central Bath & Lansdown',
#  'Bath and North East Somerset 008': 'Newbridge',
#  'Bath and North East Somerset 009': 'Kingsmead',
#  'Bath and North East Somerset 010': 'Bathavon North & South',
#  'Bath and North East Somerset 011': 'Twerton',
#  'Bath and North East Somerset 012': 'Widcombe, Bathwick Hill & Claverton Down',
#  'Bath and North East Somerset 013': 'Oldfield Park West',
#  'Bath and North East Somerset 014': 'Oldfield Park East',
#  'Bath and North East Somerset 015': 'Southdown',
#  'Bath and North East Somerset 016': 'Saltford, Farmborough & Timsbury',
#  'Bath and North East Somerset 017': 'Bloomfield',
#  'Bath and North East Somerset 018': 'Combe Down',
#  'Bath and North East Somerset 019': 'Odd Down',
#  'Bath and North East Somerset 020': 'Pensford, Clutton & Temple Cloud',
#  'Bath and North East Somerset 021': 'Chew, Bishop Sutton & East Harptree',
#  'Bath and North East Somerset 022': 'Peasedown & Bathavon West',
#  'Bath and North East Somerset 023': 'High Littleton & Paulton',
#  'Bath and North East Somerset 024': 'Radstock',
#  'Bath and North East Somerset 025': 'Midsomer Norton North',
#  'Bath and North East Somerset 026': 'Westfield',
#  'Bath and North East Somerset 027': 'Midsomer Norton Redfield',
#  'Bedford 001': 'Riseley & Sharnbrook',
#  'Bedford 002': 'Harrold, Chellington & Turvey',
#  'Bedford 003': 'Clapham, Oakley & Thurleigh',
#  'Bedford 004': 'Wyboston, Great Barford & Cople',
#  'Bedford 005': 'Brickhill',
#  'Bedford 006': 'Putnoe',
#  'Bedford 007': 'Goldington',
#  'Bedford 008': 'Bromham & Biddenham',
#  'Bedford 009': 'De Parys',
#  'Bedford 010': 'Harpur',
#  'Bedford 011': 'Newnham',
#  'Bedford 012': 'Castle & Kingsway',
#  'Bedford 013': 'Queens Park',
#  'Bedford 014': 'Kingsbrook',
#  'Bedford 015': 'Cauldwell',
#  'Bedford 016': 'Kempston North',
#  'Bedford 017': 'Kempston Central & East',
#  'Bedford 018': 'Kempston West & South',
#  'Bedford 019': 'Elstow, Shortstown & Wixams',
#  'Bedford 020': 'Wootton & Stewartby',
#  'Bexley 001': 'Crossway Park',
#  'Bexley 002': 'South Thamesmead',
#  'Bexley 003': 'Belvedere & Lessness Heath',
#  'Bexley 004': 'Erith East',
#  'Bexley 005': 'Erith West',
#  'Bexley 006': 'Lesnes Abbey',
#  'Bexley 007': 'Northumberland Heath',
#  'Bexley 008': 'Slade Green & Crayford Marshes',
#  'Bexley 009': 'Bostall',
#  'Bexley 010': 'Lesney Farm & Colyers East',
#  'Bexley 011': 'Bursted Wood',
#  'Bexley 013': "St Michael's",
#  'Bexley 014': 'Barnehurst North',
#  'Bexley 015': 'Bexleyheath Broadway',
#  'Bexley 016': 'Welling',
#  'Bexley 017': 'Barnehurst South',
#  'Bexley 018': 'Falconwood',
#  'Bexley 019': 'Crayford',
#  'Bexley 020': 'Danson Park',
#  'Bexley 021': 'Blackfen',
#  'Bexley 022': 'Lamorbey',
#  'Bexley 023': 'Bexley Village',
#  'Bexley 024': 'Albany Park',
#  'Bexley 025': 'Longlands & Halfway',
#  'Bexley 026': 'Sidcup West',
#  'Bexley 027': 'Sidcup East',
#  'Bexley 028': 'Foots Cray Meadows',
#  'Bexley 029': 'Wickham Street & East Wickham',
#  'Birmingham 001': 'Hill Hook',
#  'Birmingham 002': 'Four Oaks',
#  'Birmingham 003': 'Little Sutton & Roughley',
#  'Birmingham 004': 'Sutton Coldfield North & Park',
#  'Birmingham 005': 'Reddicap Heath',
#  'Birmingham 006': 'Rectory Park & New Hall Valley',
#  'Birmingham 007': 'Kingstanding North',
#  'Birmingham 008': 'Old Oscott',
#  'Birmingham 009': 'Sutton Coldfield South & Central',
#  'Birmingham 010': 'New Oscott',
#  'Birmingham 011': 'Kingstanding South East',
#  'Birmingham 012': 'Walmley',
#  'Birmingham 013': 'Queslett',
#  'Birmingham 014': 'Perry Common - College Road',
#  'Birmingham 015': 'Wylde Green',
#  'Birmingham 016': 'Perry Beeches West',
#  'Birmingham 017': 'Kingstanding South West',
#  'Birmingham 018': 'Chester Road',
#  'Birmingham 019': 'Perry Beeches East',
#  'Birmingham 020': 'Short Heath',
#  'Birmingham 021': 'Minworth',
#  'Birmingham 022': 'Upper Witton',
#  'Birmingham 023': 'Erdington Town',
#  'Birmingham 024': 'Perry Barr & South Hamstead',
#  'Birmingham 025': 'Pype Hayes Park',
#  'Birmingham 026': 'Stockland Green - Marsh Hill',
#  'Birmingham 028': 'Birches Green',
#  'Birmingham 029': 'Castle Vale',
#  'Birmingham 030': 'Brookvale',
#  'Birmingham 031': 'Gravelly Hill & South Erdington',
#  'Birmingham 032': 'Handsworth East',
#  'Birmingham 033': 'Birchfield East',
#  'Birmingham 034': 'Handsworth West',
#  'Birmingham 035': 'Birchfield West',
#  'Birmingham 036': 'Middlemore',
#  'Birmingham 037': 'Aston Park',
#  'Birmingham 038': 'Bromford',
#  'Birmingham 039': 'Handsworth South',
#  'Birmingham 040': 'Lozells West',
#  'Birmingham 041': 'Lozells East',
#  'Birmingham 042': 'Hodge Hill',
#  'Birmingham 043': 'Nechells',
#  'Birmingham 044': 'Ward End & Bromford West',
#  'Birmingham 045': 'Buckland End',
#  'Birmingham 046': 'Shard End & Kingfisher',
#  'Birmingham 047': 'Winson Green & Gib Heath',
#  'Birmingham 048': 'Washwood Heath',
#  'Birmingham 049': 'Hockley & Jewellery Quarter',
#  'Birmingham 050': 'North Central & Dartmouth Circus',
#  'Birmingham 051': 'Saltley East',
#  'Birmingham 052': 'Saltley West',
#  'Birmingham 053': 'Summerfield',
#  'Birmingham 054': 'Glebe Farm',
#  'Birmingham 055': 'Belchers Lane & Eastfield Road',
#  'Birmingham 056': 'Stechford',
#  'Birmingham 057': 'Kitts Green',
#  'Birmingham 058': 'Bordesley Green North',
#  'Birmingham 060': 'Rotton Park',
#  'Birmingham 062': "Kent's Moat",
#  'Birmingham 063': 'Little Bromwich',
#  'Birmingham 064': 'Edgbaston North',
#  'Birmingham 066': 'Yardley Fields',
#  'Birmingham 067': 'Yardley',
#  'Birmingham 069': 'Sheldon North',
#  'Birmingham 070': 'Small Heath Park',
#  'Birmingham 071': 'Sparkbrook North',
#  'Birmingham 072': 'Lyndon Green',
#  'Birmingham 073': 'Harborne West',
#  'Birmingham 074': 'Five Ways South & Calthorpe Park',
#  'Birmingham 075': 'Harborne East',
#  'Birmingham 076': 'Yardley South',
#  'Birmingham 077': 'Sparkbrook South',
#  'Birmingham 078': 'Hay Mills & Tyseley',
#  'Birmingham 079': 'Edgbaston South & University',
#  'Birmingham 080': 'Quinton Ridgacre',
#  'Birmingham 081': 'Sheldon South',
#  'Birmingham 082': 'Sparkhill North',
#  'Birmingham 083': 'Balsall Heath East',
#  'Birmingham 084': 'Balsall Heath West & Kingswood Road',
#  'Birmingham 085': 'Quinton East',
#  'Birmingham 087': 'Metchley',
#  'Birmingham 088': 'Moor Green & Cannon Hill',
#  'Birmingham 089': 'Acocks Green East',
#  'Birmingham 090': 'Acocks Green West',
#  'Birmingham 092': 'Moseley Village',
#  'Birmingham 093': 'Moseley',
#  'Birmingham 094': 'Woodgate Valley',
#  'Birmingham 095': 'California',
#  'Birmingham 096': 'Selly Oak',
#  'Birmingham 097': 'Springfield & Hall Green West',
#  'Birmingham 098': 'Hall Green East',
#  'Birmingham 099': 'Selly Oak Park & Lodge Hill',
#  'Birmingham 100': 'Stirchley North & Selly Park',
#  'Birmingham 101': 'Weoley Castle',
#  'Birmingham 102': 'Woodgate',
#  'Birmingham 103': 'Fox Hollies',
#  'Birmingham 104': 'Kings Heath',
#  'Birmingham 105': 'Wake Green East & Moseley Bog',
#  'Birmingham 106': 'Bartley Green & Shenley Fields',
#  'Birmingham 107': 'Kings Heath Park & Stirchley East',
#  'Birmingham 108': 'Hall Green Central',
#  'Birmingham 109': 'Shenley Lane',
#  'Birmingham 110': 'Brandwood North',
#  'Birmingham 111': 'Billesley Common',
#  'Birmingham 112': 'Bournville East & Stirchley West',
#  'Birmingham 113': 'Bournville West',
#  'Birmingham 115': 'Yardley Wood West',
#  'Birmingham 116': 'Cotteridge',
#  'Birmingham 117': 'Brandwood East',
#  'Birmingham 118': 'Brandwood End',
#  'Birmingham 119': 'Allens Cross',
#  'Birmingham 120': 'Northfield Victoria Common',
#  'Birmingham 121': 'Druids Heath',
#  'Birmingham 122': "Highter's Heath & Maypole",
#  'Birmingham 123': 'Lifford & Walkers Heath',
#  'Birmingham 124': 'Longbridge North',
#  'Birmingham 125': 'Frankley',
#  'Birmingham 126': 'Turves Green',
#  'Birmingham 127': "King's Norton",
#  'Birmingham 128': 'Hawkesley',
#  'Birmingham 129': 'Longbridge South',
#  'Birmingham 130': 'Rubery East',
#  'Birmingham 131': 'West Heath',
#  'Birmingham 132': 'Yardley Wood East',
#  'Birmingham 133': 'Handsworth Wood',
#  'Birmingham 134': 'Attwood Green & Park Central',
#  'Birmingham 135': 'Digbeth',
#  'Birmingham 136': 'Five Ways North',
#  'Birmingham 137': 'Ladywood - Summer Hill',
#  'Birmingham 138': 'Central',
#  'Birmingham 139': 'Bordesley',
#  'Birmingham 140': 'Greet & Sparkhill South',
#  'Blaby 002': 'Leicester Forest East',
#  'Blaby 003': 'Kirby Muxloe & Thurlaston',
#  'Blaby 004': 'Thorpe Astley',
#  'Blaby 005': 'Braunstone Town',
#  'Blaby 006': 'Enderby & Glen Parva',
#  'Blaby 007': 'Narborough',
#  'Blaby 008': 'Blaby Village',
#  'Blaby 009': 'Whetstone',
#  'Blaby 010': 'Cosby, Croft & Elmesthorpe',
#  'Blaby 011': 'Countesthorpe & Kilby',
#  'Blaby 012': 'Stoney Stanton, Sapcote & Sharnford',
#  'Blaby 013': 'Glenfield',
#  'Blackburn with Darwen 001': 'Roe Lee, Brownhill & Sunnybower',
#  'Blackburn with Darwen 002': 'Lammack & Revidge',
#  'Blackburn with Darwen 003': 'Little Harwood',
#  'Blackburn with Darwen 004': 'Bastwell',
#  'Blackburn with Darwen 005': 'Wensley Fold',
#  'Blackburn with Darwen 006': 'Central Blackburn',
#  'Blackburn with Darwen 007': 'Audley',
#  'Blackburn with Darwen 008': 'Shadsworth & Intack',
#  'Blackburn with Darwen 009': 'Witton, Mill Hill & Hollin Bank',
#  'Blackburn with Darwen 010': 'Beardwood, Pleasington & Livesey',
#  'Blackburn with Darwen 011': "Queen's Park & Higher Croft",
#  'Blackburn with Darwen 012': 'Meadowhead',
#  'Blackburn with Darwen 013': 'Ewood & Fernhurst',
#  'Blackburn with Darwen 014': 'North Darwen',
#  'Blackburn with Darwen 015': 'East Darwen',
#  'Blackburn with Darwen 016': 'Darwen Town',
#  'Blackburn with Darwen 017': 'South Darwen & Whitehall',
#  'Blackburn with Darwen 018': 'Tockholes, Edgworth & Hoddlesden',
#  'Blackpool 001': 'Little Bispham & Anchorsholme',
#  'Blackpool 002': 'Churchtown',
#  'Blackpool 003': 'Norbreck & Bispham',
#  'Blackpool 004': 'Warbreck & Bispham Road',
#  'Blackpool 005': 'Hoohill',
#  'Blackpool 006': 'North Shore',
#  'Blackpool 007': 'Little Layton & Little Carleton',
#  'Blackpool 008': 'North East Centre',
#  'Blackpool 009': 'Queenstown & Layton',
#  'Blackpool 010': 'Central Blackpool',
#  'Blackpool 011': 'Park Road',
#  'Blackpool 012': 'Stanley Park & Great Marton',
#  'Blackpool 013': 'South Promenade & Seasiders Way',
#  'Blackpool 014': 'Little Marton & Marton Moss Side',
#  'Blackpool 015': 'Victoria',
#  'Blackpool 016': 'Hawes Side',
#  'Blackpool 017': 'South Shore',
#  'Blackpool 018': 'Common Edge',
#  'Blackpool 019': 'Squires Gate',
#  'Blaenau Gwent 001': 'Rassau & Beaufort',
#  'Blaenau Gwent 002': 'Bryn-mawr',
#  'Blaenau Gwent 003': 'Sirhowy',
#  'Blaenau Gwent 004': 'Ebbw Vale North & Glyncoed',
#  'Blaenau Gwent 005': 'Blaina & Nantyglo',
#  'Blaenau Gwent 006': 'Tredegar & Georgetown',
#  'Blaenau Gwent 007': 'Ebbw Vale South & Cwm',
#  'Blaenau Gwent 008': 'Abertillery North & Cwmtillery',
#  'Blaenau Gwent 009': 'Abertillery South & Llanhilleth',
#  'Bolsover 001': 'Clowne & Barlborough',
#  'Bolsover 002': 'Whitwell & Elmton',
#  'Bolsover 003': 'Creswell & Hodthorpe',
#  'Bolsover 004': 'Bolsover North & Shuttlewood',
#  'Bolsover 005': 'Bolsover South & Glapwell',
#  'Bolsover 006': 'Shirebrook North',
#  'Bolsover 007': 'Langwith, Shirebrook South & Pleasley',
#  'Bolsover 008': 'Tibshelf, Newton & Hardwick Park',
#  'Bolsover 009': 'South Normanton West',
#  'Bolsover 010': 'South Normanton Broadmeadows & Pinxton',
#  'Bolton 001': 'Dunscar & Egerton',
#  'Bolton 002': 'Bromley Cross & Bradshaw',
#  'Bolton 003': 'Eagley & Sharples',
#  'Bolton 004': 'Horwich North',
#  'Bolton 005': 'Astley Bridge & Waters Meeting',
#  'Bolton 006': 'Harwood',
#  'Bolton 007': 'Horwich South & Middlebrook',
#  'Bolton 008': 'Smithills',
#  'Bolton 009': 'Blackrod & Butterwick Fields',
#  'Bolton 010': "Hall I' th' Wood",
#  'Bolton 011': 'Halliwell & Brownlow Fold',
#  'Bolton 012': 'Doffcocker & Moss Bank',
#  'Bolton 013': 'Breightmet North',
#  'Bolton 014': 'Horwich East',
#  'Bolton 015': 'Gilnow & Victory',
#  'Bolton 016': 'Central Bolton',
#  'Bolton 017': 'Tonge',
#  'Bolton 018': 'Heaton & Deane',
#  'Bolton 019': 'Breightmet South & Darcy Lever',
#  'Bolton 020': 'Lostock & Ladybridge',
#  'Bolton 021': 'Rumworth North',
#  'Bolton 022': 'Burnden & Great Lever',
#  'Bolton 023': 'Rumworth South',
#  'Bolton 024': 'Little Lever',
#  'Bolton 025': 'Lever Edge',
#  'Bolton 026': 'Daubhill & Fernhill Gate',
#  'Bolton 027': 'Farnworth North',
#  'Bolton 028': 'Westhoughton East',
#  'Bolton 029': 'Harper Green',
#  'Bolton 030': 'Over Hulton',
#  'Bolton 031': 'Westhoughton West',
#  'Bolton 032': 'Farnworth South',
#  'Bolton 033': 'Highfield & New Bury',
#  'Bolton 034': 'Kearsley & Stoneclough',
#  'Bolton 035': 'Westhoughton Daisy Hill',
#  'Boston 001': 'Leake & Butterwick',
#  'Boston 002': 'Fenside & Lister Way',
#  'Boston 003': 'Boston Central & North',
#  'Boston 004': 'Skirbeck',
#  'Boston 006': 'Swineshead, Bicker & Holland Fen',
#  'Boston 007': 'Kirton, Frampton & Algarkirk',
#  'Boston 008': 'Fishtoft & Wyberton East',
#  'Boston 009': 'Wyberton West & Fen',
#  'Bournemouth 001': 'Kinson East',
#  'Bournemouth 002': 'Kinson West',
#  'Bournemouth 003': 'Northbourne',
#  'Bournemouth 004': 'Throop & Muscliffe',
#  'Bournemouth 005': 'West Howe',
#  'Bournemouth 006': 'Moordown',
#  'Bournemouth 007': 'East Howe & Ensbury Park',
#  'Bournemouth 008': 'Townsend & Strouden',
#  'Bournemouth 009': 'Winton',
#  'Bournemouth 010': 'Queens Park',
#  'Bournemouth 011': 'Littledown',
#  'Bournemouth 012': 'Talbot & Branksome Woods',
#  'Bournemouth 013': 'Charminster',
#  'Bournemouth 014': 'Iford',
#  'Bournemouth 015': "Springbourne & Queen's Park",
#  'Bournemouth 016': 'Boscombe East',
#  'Bournemouth 017': 'Central Bournemouth',
#  'Bournemouth 018': 'Southbourne West',
#  'Bournemouth 019': 'Boscombe West',
#  'Bournemouth 020': 'East Southbourne & Hengistbury Head',
#  'Bournemouth 021': 'East Cliff',
#  'Bournemouth 023': 'Westbourne',
#  'Bournemouth 024': 'West Cliff',
#  'Bracknell Forest 001': 'Winkfield & Cranbourne',
#  'Bracknell Forest 002': 'Binfield & Popeswood',
#  'Bracknell Forest 003': 'Wick Hill',
#  'Bracknell Forest 004': 'Priestwood',
#  'Bracknell Forest 005': 'Chavey Down & North Ascot West',
#  'Bracknell Forest 006': 'Bullbrook',
#  'Bracknell Forest 007': 'Central Bracknell & Wildridings',
#  'Bracknell Forest 008': 'Crown Wood',
#  'Bracknell Forest 009': 'Great Hollands',
#  'Bracknell Forest 010': 'Birch Hill & Hanworth East',
#  'Bracknell Forest 011': 'Hanworth West',
#  'Bracknell Forest 012': 'Crowthorne South',
#  'Bracknell Forest 013': 'Owlsmoor & Broadmoor',
#  'Bracknell Forest 014': 'Sandhurst',
#  'Bracknell Forest 015': 'College Town',
#  'Bradford 001': 'Addingham & Ilkley Moor',
#  'Bradford 002': 'Ilkley & Ben Rhydding',
#  'Bradford 003': 'Burley-in-Wharfedale',
#  'Bradford 004': 'Steeton & Silsden',
#  'Bradford 005': 'Menston & Burley Moor',
#  'Bradford 006': 'Riddlesden & East Morton',
#  'Bradford 007': 'Keighley Utley',
#  'Bradford 008': 'Keighley Central & East',
#  'Bradford 009': 'Keighley Oakworth Road & West Lane',
#  'Bradford 010': 'Crossflatts & Eldwick',
#  'Bradford 011': 'Keighley South',
#  'Bradford 012': 'Keighley Exley Head',
#  'Bradford 013': 'Baildon North',
#  'Bradford 014': 'Oakworth & Laycock',
#  'Bradford 015': 'Bingley Town',
#  'Bradford 016': 'Baildon South',
#  'Bradford 017': 'Thackley & Esholt',
#  'Bradford 018': 'Saltaire & Baildon West',
#  'Bradford 019': 'Idle',
#  'Bradford 020': 'Shipley Town',
#  'Bradford 021': 'Windhill',
#  'Bradford 022': 'Cottingley, Harden & Wilsden',
#  'Bradford 023': 'Haworth & Oxenhope',
#  'Bradford 024': 'Wrose & Bolton Woods',
#  'Bradford 025': 'Frizinghall & Heaton Grove',
#  'Bradford 026': 'Eccleshill',
#  'Bradford 027': 'Ravenscliffe',
#  'Bradford 028': 'Bolton Road & Kings Road',
#  'Bradford 029': 'Heaton Highgate',
#  'Bradford 030': 'Chellow Heights',
#  'Bradford 031': 'Cullingworth & Denholme',
#  'Bradford 032': 'Haigh Fold',
#  'Bradford 033': 'Toller Lane & Infirmary',
#  'Bradford 034': 'Manningham & Lister Park',
#  'Bradford 035': 'Undercliffe',
#  'Bradford 036': 'Allerton',
#  'Bradford 037': 'Girlington',
#  'Bradford 038': 'Thornbury',
#  'Bradford 039': 'Central Bradford & Barkerend West',
#  'Bradford 040': 'Fairweather Green',
#  'Bradford 041': 'Brown Royd',
#  'Bradford 042': 'Barkerend East',
#  'Bradford 043': 'Thornton',
#  'Bradford 044': 'Shearbridge & University',
#  'Bradford 045': 'Broomfields & East Bowling',
#  'Bradford 046': 'Laisterdyke & Bowling',
#  'Bradford 047': 'Clayton',
#  'Bradford 048': 'Holme Top',
#  'Bradford 049': 'Scholemoor',
#  'Bradford 050': 'Great Horton & Brackenhill',
#  'Bradford 051': 'Canterbury',
#  'Bradford 052': 'Holme Wood',
#  'Bradford 053': 'Bowling Park',
#  'Bradford 054': "Wibsey St Enoch's",
#  'Bradford 055': 'Horton Bank',
#  'Bradford 056': 'Bankfoot',
#  'Bradford 057': 'Bierley & Tong',
#  'Bradford 058': 'Queensbury',
#  'Bradford 059': 'Buttershaw',
#  'Bradford 060': 'Low Moor',
#  'Bradford 061': 'Wyke',
#  'Braintree 001': 'Steeple Bumpstead & Great Yeldham',
#  'Braintree 002': 'Bures Hamlet, Maplestead & Belchamp',
#  'Braintree 003': 'Hedingham, Gosfield & Greenstead Green',
#  'Braintree 004': 'Halstead Central & West',
#  'Braintree 005': 'Panfield, Finchingfield & Bardfield',
#  'Braintree 006': 'Halstead East & Colnes',
#  'Braintree 007': 'Bocking Churchstreet & Blackwater',
#  'Braintree 008': 'Bocking',
#  'Braintree 009': 'Central Braintree',
#  'Braintree 010': 'Braintree West & Rayne',
#  'Braintree 011': 'Braintree South',
#  'Braintree 012': 'Silver End & Stisted',
#  'Braintree 013': 'Great Notley & Black Notley',
#  'Braintree 014': 'Coggeshall & Kelvedon',
#  'Braintree 015': 'North Witham',
#  'Braintree 016': 'West Witham',
#  'Braintree 017': 'Witham Town',
#  'Braintree 018': 'Witham South, Hatfield Peverel & White Notley',
#  'Breckland 001': 'Bawdeswell, Swanton Morley & North Elmham',
#  'Breckland 002': 'Whissonsett, Litcham & Narborough',
#  'Breckland 003': 'Dereham North & Neatherd',
#  'Breckland 004': 'Dereham West, Necton & Gressenhall',
#  'Breckland 005': 'Dereham Central & Toftwood',
#  'Breckland 006': 'Hockering, Mattishall & Cranworth',
#  'Breckland 007': 'Swaffham',
#  'Breckland 008': 'Shipdham, Bradenham & Saham Toney',
#  'Breckland 009': 'Watton',
#  'Breckland 010': 'Wayland, Ellingham & Great Hockham',
#  'Breckland 011': 'Attleborough',
#  'Breckland 012': 'Mundford, Weeting & Forest',
#  'Breckland 013': 'Buckenhams & Snetterton',
#  'Breckland 014': 'East Harling, Garboldisham & Kenninghall',
#  'Breckland 015': 'Thetford North',
#  'Breckland 016': 'Thetford Central & East',
#  'Breckland 017': 'Thetford South',
#  'Brent 001': 'Queensbury South',
#  'Brent 002': 'Kingsbury East & Colindale',
#  'Brent 003': 'Kingsbury West',
#  'Brent 004': 'Kenton Woodcock Park',
#  'Brent 005': 'Kingsbury South',
#  'Brent 006': 'Barnhill The Avenue',
#  'Brent 007': 'Preston Park & East Lane',
#  'Brent 008': 'Northwick Park',
#  'Brent 009': 'Forty Lane',
#  'Brent 010': 'Welsh Harp',
#  'Brent 011': 'Dollis Hill',
#  'Brent 012': 'Wembley North',
#  'Brent 013': 'Sudbury East',
#  'Brent 014': 'Neasden',
#  'Brent 015': 'Cricklewood Anson Road',
#  'Brent 016': 'Sudbury West',
#  'Brent 017': 'Tokyngton',
#  'Brent 018': 'Dudden Hill',
#  'Brent 019': 'Wembley West',
#  'Brent 020': 'Wembley East',
#  'Brent 021': 'St Raphaels',
#  'Brent 022': 'Willesden Green',
#  'Brent 023': 'Brondesbury',
#  'Brent 024': 'Roundwood Park',
#  'Brent 025': 'Church End',
#  'Brent 026': 'Alperton East',
#  'Brent 027': 'Stonebridge',
#  'Brent 028': 'Kilburn West',
#  'Brent 029': 'Alperton West',
#  'Brent 030': 'Brondesbury Park',
#  'Brent 031': 'Harlesden',
#  'Brent 032': 'Queens Park',
#  'Brent 033': 'Kensal Green',
#  'Brent 034': 'Kilburn Park',
#  'Brentwood 001': 'Kelvedon Hatch & Doddinghurst',
#  'Brentwood 002': 'Ingatestone & Mountnessing',
#  'Brentwood 003': 'Hutton',
#  'Brentwood 004': 'Brentwood North',
#  'Brentwood 005': 'Shenfield & Hutton Mount',
#  'Brentwood 006': "Brook Street & Pilgrim's Hatch",
#  'Brentwood 007': 'Brentwood Central',
#  'Brentwood 008': 'Brentwood South & Warley',
#  'Brentwood 009': 'Herongate, Ingrave & West Horndon',
#  'Bridgend 001': 'Caerau',
#  'Bridgend 002': 'Maesteg East',
#  'Bridgend 003': 'Nant-y-moel, Ogmore Vale & Blackmill',
#  'Bridgend 004': 'Blaengarw, Pontycymer & Bettws',
#  'Bridgend 005': 'Maesteg West, Garth & Llangynwyd',
#  'Bridgend 006': 'Ynysawdre & Aberkenfig',
#  'Bridgend 007': 'Sarn, Bryn-coch & Bryncethin',
#  'Bridgend 008': 'Pyle, Kenfig Hill & Cefncribwr',
#  'Bridgend 009': 'Pen-prysg, Hendre & Felindre',
#  'Bridgend 010': 'Cornelly',
#  'Bridgend 011': 'Pen-dre, Litchard & Coity',
#  'Bridgend 012': 'Cefn-glas & Bryntirion',
#  'Bridgend 013': 'Pen-y-fai, Laleston & Merthyr Mawr',
#  'Bridgend 014': 'Central Bridgend',
#  'Bridgend 015': 'Brackla East & Coychurch Lower',
#  'Bridgend 016': 'Brackla West',
#  'Bridgend 017': 'Broadlands',
#  'Bridgend 018': 'Porthcawl West',
#  'Bridgend 019': 'Porthcawl East',
#  'Brighton and Hove 001': 'Patcham East',
#  'Brighton and Hove 002': 'Coldean & Moulsecoomb North',
#  'Brighton and Hove 003': 'Patcham West & Westdene',
#  'Brighton and Hove 004': 'Hollingbury',
#  'Brighton and Hove 005': 'Mile Oak',
#  'Brighton and Hove 006': 'Hangleton North',
#  'Brighton and Hove 007': 'West Blatchington',
#  'Brighton and Hove 008': 'Hollingdean & Moulsecoomb West',
#  'Brighton and Hove 009': 'Bevendean & Moulsecoomb East',
#  'Brighton and Hove 010': 'Fiveways',
#  'Brighton and Hove 011': 'Withdean Woods',
#  'Brighton and Hove 012': 'Portslade Village',
#  'Brighton and Hove 013': 'Hangleton South',
#  'Brighton and Hove 014': 'Preston Park',
#  'Brighton and Hove 015': 'Round Hill',
#  'Brighton and Hove 016': 'Aldrington',
#  'Brighton and Hove 017': 'Woodingdean',
#  'Brighton and Hove 018': 'Elm Grove & Bear Road',
#  'Brighton and Hove 019': 'Goldsmid West',
#  'Brighton and Hove 020': 'Goldsmid East',
#  'Brighton and Hove 021': 'Portslade by Sea',
#  'Brighton and Hove 022': 'Hanover',
#  'Brighton and Hove 023': 'Aldrington South',
#  'Brighton and Hove 024': 'Seven Dials',
#  'Brighton and Hove 025': 'Whitehawk',
#  'Brighton and Hove 026': 'Hove Central',
#  'Brighton and Hove 027': 'North Laine & the Lanes',
#  'Brighton and Hove 028': 'King Alfred',
#  'Brighton and Hove 029': 'Brunswick',
#  'Brighton and Hove 030': "St James's Street & Queen's Park",
#  'Brighton and Hove 031': 'Kemptown',
#  'Brighton and Hove 032': 'Roedean & Marina',
#  'Brighton and Hove 033': 'Rottingdean & Saltdean',
#  'Bristol 001': 'Henbury & Brentry',
#  'Bristol 002': 'Southmead',
#  'Bristol 003': 'Lawrence Weston',
#  'Bristol 004': 'Monks Park',
#  'Bristol 005': 'Upper Horfield',
#  'Bristol 006': 'Westbury Village',
#  'Bristol 007': 'Sea Mills',
#  'Bristol 008': 'Shirehampton & Avonmouth',
#  'Bristol 009': 'Westbury on Trym',
#  'Bristol 010': 'Horfield',
#  'Bristol 011': 'Henleaze',
#  'Bristol 012': 'Stapleton',
#  'Bristol 013': 'Fishponds North',
#  'Bristol 014': 'Lockleaze',
#  'Bristol 015': 'Stoke Bishop',
#  'Bristol 016': 'Bishopston',
#  'Bristol 017': 'Westbury Park',
#  'Bristol 018': 'Fishponds South',
#  'Bristol 019': 'Eastville',
#  'Bristol 020': "Redland & St Andrew's",
#  'Bristol 021': 'Speedwell',
#  'Bristol 022': 'Cotham',
#  'Bristol 023': "St Paul's",
#  'Bristol 025': 'Kingsdown & Stokes Croft',
#  'Bristol 026': 'Clifton East',
#  'Bristol 027': 'Two Mile Hill',
#  'Bristol 028': 'St George',
#  'Bristol 029': 'Redfield',
#  'Bristol 030': 'Clifton Village',
#  'Bristol 032': 'Bristol City Centre',
#  'Bristol 033': 'Crews Hole',
#  'Bristol 034': 'Hotwells',
#  'Bristol 035': 'St Annes',
#  'Bristol 036': 'Southville',
#  'Bristol 037': 'Totterdown',
#  'Bristol 038': 'Broom Hill',
#  'Bristol 039': 'Bedminster',
#  'Bristol 040': 'Windmill Hill',
#  'Bristol 041': 'Ashton',
#  'Bristol 042': 'Knowle Park',
#  'Bristol 043': 'Brislington',
#  'Bristol 044': 'Knowle',
#  'Bristol 045': 'Knowle West',
#  'Bristol 046': 'Bishopsworth',
#  'Bristol 047': 'Hengrove',
#  'Bristol 048': 'Headley Park',
#  'Bristol 049': 'Stockwood',
#  'Bristol 050': 'Highridge',
#  'Bristol 051': 'Withywood',
#  'Bristol 052': 'Whitchurch Park',
#  'Bristol 053': 'Hartcliffe',
#  'Bristol 054': 'Temple Meads',
#  'Bristol 055': 'Upper Easton',
#  'Bristol 056': 'Barton Hill',
#  'Bristol 057': 'Lower Easton',
#  'Broadland 001': 'Aylsham',
#  'Broadland 002': 'Reepham, Cawston & Lenwade',
#  'Broadland 003': 'Coltishall, Buxton & Frettenham',
#  'Broadland 004': 'Horsford, Hainford & Hevingham',
#  'Broadland 005': 'Spixworth & St Faiths',
#  'Broadland 006': 'Taverham',
#  'Broadland 007': 'Drayton & Thorpe Marriott',
#  'Broadland 008': 'Wroxham, Rackheath & the Plumsteads',
#  'Broadland 009': 'Old Catton',
#  'Broadland 010': 'Hellesdon North West',
#  'Broadland 011': 'Hellesdon South East',
#  'Broadland 012': 'Sprowston Central',
#  'Broadland 013': 'Sprowston East',
#  'Broadland 014': 'Blofield, Lingwood & Upton',
#  'Broadland 015': 'Thorpe St Andrew North',
#  'Broadland 016': 'Thorpe St Andrew South & Dussindale',
#  'Broadland 017': 'Brundall & Cantley',
#  'Broadland 018': 'Acle & Reedham',
#  'Bromley 001': 'Mottingham',
#  'Bromley 002': 'Chislehurst North',
#  'Bromley 004': 'Penge East',
#  'Bromley 005': 'Crystal Palace Park',
#  'Bromley 006': 'New Beckenham',
#  'Bromley 007': 'Chislehurst West & Elmstead',
#  'Bromley 008': 'Bromley North & Sundridge',
#  'Bromley 009': 'Anerley North & Penge West',
#  'Bromley 010': 'Chislehurst East & Hoblingwell Wood',
#  'Bromley 011': 'Shortlands Bromley Road',
#  'Bromley 012': 'Beckenham East & Kelsey Park',
#  'Bromley 013': 'Clock House & Cator Park',
#  'Bromley 014': 'St Mary Cray North',
#  'Bromley 015': 'Anerley South',
#  'Bromley 016': 'Widmore',
#  'Bromley 018': 'Bromley South',
#  'Bromley 019': 'St Mary Cray East',
#  'Bromley 020': 'Bickley West',
#  'Bromley 021': 'Langley Park',
#  'Bromley 022': 'Bickley East',
#  'Bromley 023': 'St Mary Cray South',
#  'Bromley 024': 'Eden Park & Bethlem',
#  'Bromley 025': 'Petts Wood',
#  'Bromley 026': 'Bromley Common',
#  'Bromley 027': 'Hayes North',
#  'Bromley 028': 'Orpington West',
#  'Bromley 029': 'Orpington East',
#  'Bromley 030': 'West Wickham',
#  'Bromley 031': 'Crofton',
#  'Bromley 032': 'Goddington',
#  'Bromley 033': 'Keston',
#  'Bromley 034': 'Hayes South & Coney Hall',
#  'Bromley 035': 'Orpington South',
#  'Bromley 036': 'Farnborough',
#  'Bromley 037': 'Chelsfield & Green Street Green',
#  'Bromley 039': 'Biggin Hill West',
#  'Bromley 040': 'Plaistow (Bromley)',
#  'Bromley 041': 'Elmers End',
#  'Bromley 042': 'Biggin Hill East & Cudham',
#  'Bromsgrove 001': 'Hagley',
#  'Bromsgrove 002': 'Dodford, Belbroughton & Romsley',
#  'Bromsgrove 003': 'Rubery West',
#  'Bromsgrove 004': 'Hollywood & Drakes Cross',
#  'Bromsgrove 005': 'Wythall & Gay Hill',
#  'Bromsgrove 006': 'Barnt Green & Lickey Hills',
#  'Bromsgrove 007': 'Catshill',
#  'Bromsgrove 008': 'Marlbrook & Lickey End',
#  'Bromsgrove 009': 'Alvechurch, Hopwood & Holt End',
#  'Bromsgrove 010': 'Bromsgrove Sidemoor',
#  'Bromsgrove 011': 'Bromsgrove Central & Sanders Park',
#  'Bromsgrove 012': 'Bromsgrove Stoney Hill',
#  'Bromsgrove 013': 'Bromsgrove Charford',
#  'Bromsgrove 014': 'Stoke Heath, Finstall & Bentley',
#  'Broxbourne 001': 'Hoddesdon Ware Road',
#  'Broxbourne 002': 'Rye Park',
#  'Broxbourne 003': 'Hoddesdon Town',
#  'Broxbourne 004': 'Broxbourne Town',
#  'Broxbourne 005': 'Wormley & Turnford',
#  'Broxbourne 006': 'Flamstead End',
#  'Broxbourne 007': 'Goffs Oak',
#  'Broxbourne 008': 'Cheshunt Coopers Walk',
#  'Broxbourne 009': 'Rosedale',
#  'Broxbourne 010': 'Cheshunt Central',
#  'Broxbourne 011': 'Churchgate',
#  'Broxbourne 012': 'Cheshunt South',
#  'Broxbourne 013': 'Waltham Cross Town',
#  'Broxtowe 001': 'Eastwood Hall & Brinsley',
#  'Broxtowe 002': 'Eastwood Town',
#  'Broxtowe 003': 'Eastwood East',
#  'Broxtowe 004': 'Kimberley North & Watnall',
#  'Broxtowe 007': 'Bramcote',
#  'Broxtowe 008': 'Stapleford North',
#  'Broxtowe 009': 'Beeston North',
#  'Broxtowe 010': 'Stapleford South',
#  'Broxtowe 011': 'Beeston Town',
#  'Broxtowe 012': 'Beeston Rylands',
#  'Broxtowe 013': 'Chilwell West',
#  'Broxtowe 014': 'Attenborough & Chilwell East',
#  'Broxtowe 015': 'Toton',
#  'Broxtowe 016': 'Kimberley South, Trowell & Awsworth',
#  'Burnley 001': 'Harle Syke & Lanehead',
#  'Burnley 002': 'Queensgate',
#  'Burnley 003': 'Central Burnley & Daneshouse',
#  'Burnley 004': 'Padiham',
#  'Burnley 005': 'Habergham & Ightenhill',
#  'Burnley 006': 'Whittlefield & Rose Grove',
#  'Burnley 007': 'Bank Hall & Fulledge',
#  'Burnley 008': 'Brunshaw & Brownside',
#  'Burnley 009': 'Cliviger, Worsthorne & Lane Bottom',
#  'Burnley 010': 'Barclay Hills & Trinity',
#  'Burnley 011': 'Hapton & Lowerhouse',
#  'Burnley 014': 'Rose Hill & Burnley Wood',
#  'Bury 001': 'Ramsbottom',
#  'Bury 002': 'Summerseat',
#  'Bury 003': 'Nuttall & Tottington',
#  'Bury 004': 'Walmersley & Limefield',
#  'Bury 005': 'Higher Woodhill',
#  'Bury 006': 'Walshaw & Woolfold',
#  'Bury 007': 'Fairfield & Jericho',
#  ...}

# %% [markdown]
# ## Dataset location

# %%
dataset_path = input("Enter the path to the dataset folder: ")

# %% [markdown]
# ## Import data

# %% [markdown]
# Train set (2012-2018)

# %%
trainSet = getAllFiles(dataset_path, "street", 2012, 1, 2018, 12,
                       included_columns=['Month', 'LSOA name', 'Crime type'], msoa_dictionary=msoa_dict)
trainSet
# Out:
# 100%|██████████| 132/132 [01:55<00:00,  1.14it/s]
#             Month                          LSOA name  \
# 0         2012-01  Bath and North East Somerset 001A
# 1         2012-01  Bath and North East Somerset 001A
# 2         2012-01  Bath and North East Somerset 001A
# 3         2012-01  Bath and North East Somerset 001A
# 4         2012-01  Bath and North East Somerset 001A
# ...           ...                                ...
# 40834957  2018-12                     Wiltshire 062E
# 40834958  2018-12                     Wiltshire 062E
# 40834959  2018-12                     Wiltshire 062E
# 40834960  2018-12                     Wiltshire 062E
# 40834961  2018-12                     Wiltshire 062E
#
#                             Crime type                     MSOA
# 0                Anti-social behaviour           Keynsham North
# 1                Anti-social behaviour           Keynsham North
# 2                Anti-social behaviour           Keynsham North
# 3                          Other theft           Keynsham North
# 4                          Other theft           Keynsham North
# ...                                ...                      ...
# 40834957                  Public order  Downton & Morgan's Vale
# 40834958                 Vehicle crime  Downton & Morgan's Vale
# 40834959  Violence and sexual offences  Downton & Morgan's Vale
# 40834960  Violence and sexual offences  Downton & Morgan's Vale
# 40834961  Violence and sexual offences  Downton & Morgan's Vale
#
# [40834962 rows x 4 columns]

# %% [markdown]
# Test set no covid (split on March 2020)

# %%
# test set
testSetNoCovid = getAllFiles(dataset_path, "street", 2019, 1, 2020, 2,
                             included_columns=['Month', 'LSOA name', 'Crime type'], msoa_dictionary=msoa_dict)
testSetNoCovid
# Out:
# 100%|██████████| 132/132 [00:32<00:00,  4.03it/s]
#             Month                          LSOA name  \
# 0         2019-01  Bath and North East Somerset 001A
# 1         2019-01  Bath and North East Somerset 001A
# 2         2019-01  Bath and North East Somerset 001A
# 3         2019-01  Bath and North East Somerset 001A
# 4         2019-01  Bath and North East Somerset 001A
# ...           ...                                ...
# 12279031  2020-12                     Wiltshire 062E
# 12279032  2020-12                     Wiltshire 062E
# 12279033  2020-12                     Wiltshire 062E
# 12279034  2020-12                     Wiltshire 062E
# 12279035  2020-12                     Wiltshire 062E
#
#                             Crime type                     MSOA
# 0                Anti-social behaviour           Keynsham North
# 1            Criminal damage and arson           Keynsham North
# 2            Criminal damage and arson           Keynsham North
# 3                          Other theft           Keynsham North
# 4                          Other theft           Keynsham North
# ...                                ...                      ...
# 12279031     Criminal damage and arson  Downton & Morgan's Vale
# 12279032  Violence and sexual offences  Downton & Morgan's Vale
# 12279033  Violence and sexual offences  Downton & Morgan's Vale
# 12279034  Violence and sexual offences  Downton & Morgan's Vale
# 12279035  Violence and sexual offences  Downton & Morgan's Vale
#
# [12279036 rows x 4 columns]

# %% [markdown]
# Test set covid (split on March 2020)

# %%
# start of march covid measures in uk
testSetCovid = getAllFiles(dataset_path, "street", 2020, 3, 2021, 10,
                           included_columns=['Month', 'LSOA name', 'Crime type'], msoa_dictionary=msoa_dict)
testSetCovid
# Out:
# 100%|██████████| 132/132 [00:28<00:00,  4.56it/s]
#             Month                          LSOA name  \
# 0         2020-01  Bath and North East Somerset 001A
# 1         2020-01  Bath and North East Somerset 001A
# 2         2020-01  Bath and North East Somerset 001A
# 3         2020-01  Bath and North East Somerset 001A
# 4         2020-01  Bath and North East Somerset 001A
# ...           ...                                ...
# 10837197  2021-10                     Wiltshire 062E
# 10837198  2021-10                     Wiltshire 062E
# 10837199  2021-10                     Wiltshire 062E
# 10837200  2021-10                     Wiltshire 062E
# 10837201  2021-10                     Wiltshire 062E
#
#                             Crime type                     MSOA
# 0                Anti-social behaviour           Keynsham North
# 1                             Burglary           Keynsham North
# 2                             Burglary           Keynsham North
# 3                          Other theft           Keynsham North
# 4                          Other theft           Keynsham North
# ...                                ...                      ...
# 10837197     Criminal damage and arson  Downton & Morgan's Vale
# 10837198                  Public order  Downton & Morgan's Vale
# 10837199                 Vehicle crime  Downton & Morgan's Vale
# 10837200  Violence and sexual offences  Downton & Morgan's Vale
# 10837201  Violence and sexual offences  Downton & Morgan's Vale
#
# [10837202 rows x 4 columns]

# %% [markdown]
# Complete dataset

# %%
completeSet = pd.concat([trainSet, testSetNoCovid, testSetCovid], axis=0, ignore_index=True)
completeSet
# Out:
#             Month                          LSOA name  \
# 0         2012-01  Bath and North East Somerset 001A
# 1         2012-01  Bath and North East Somerset 001A
# 2         2012-01  Bath and North East Somerset 001A
# 3         2012-01  Bath and North East Somerset 001A
# 4         2012-01  Bath and North East Somerset 001A
# ...           ...                                ...
# 63951195  2021-10                     Wiltshire 062E
# 63951196  2021-10                     Wiltshire 062E
# 63951197  2021-10                     Wiltshire 062E
# 63951198  2021-10                     Wiltshire 062E
# 63951199  2021-10                     Wiltshire 062E
#
#                             Crime type                     MSOA
# 0                Anti-social behaviour           Keynsham North
# 1                Anti-social behaviour           Keynsham North
# 2                Anti-social behaviour           Keynsham North
# 3                          Other theft           Keynsham North
# 4                          Other theft           Keynsham North
# ...                                ...                      ...
# 63951195     Criminal damage and arson  Downton & Morgan's Vale
# 63951196                  Public order  Downton & Morgan's Vale
# 63951197                 Vehicle crime  Downton & Morgan's Vale
# 63951198  Violence and sexual offences  Downton & Morgan's Vale
# 63951199  Violence and sexual offences  Downton & Morgan's Vale
#
# [63951200 rows x 4 columns]

# %% [markdown]
# ## Replace values that changed throughout years

# %%
trainSet['Crime type'] = trainSet['Crime type'].replace('Violent crime', 'Violence and sexual offences')
trainSet['Crime type'] = trainSet['Crime type'].replace('Public disorder and weapons','Other crime')

# %%
testSetNoCovid['Crime type'] = testSetNoCovid['Crime type'].replace('Violent crime', 'Violence and sexual offences')
testSetNoCovid['Crime type'] = testSetNoCovid['Crime type'].replace('Public disorder and weapons','Other crime')

# %%
completeSet['Crime type'] = completeSet['Crime type'].replace('Violent crime', 'Violence and sexual offences')
completeSet['Crime type'] = completeSet['Crime type'].replace('Public disorder and weapons','Other crime')

# %% [markdown]
# ## Count crime type per MSOA per month

# %%
trainSetCount = countMSOA(trainSet)
trainSetCount
# Out:
#            Month                           MSOA                    Crime type  \
# 0        2012-01  Abberley, Holt Heath & Hallow         Anti-social behaviour
# 1        2012-01  Abberley, Holt Heath & Hallow                 Bicycle theft
# 2        2012-01  Abberley, Holt Heath & Hallow                      Burglary
# 3        2012-01  Abberley, Holt Heath & Hallow     Criminal damage and arson
# 4        2012-01  Abberley, Holt Heath & Hallow                         Drugs
# ...          ...                            ...                           ...
# 8385281  2018-12     Ystradgynlais & Tawe Uchaf                       Robbery
# 8385282  2018-12     Ystradgynlais & Tawe Uchaf                   Shoplifting
# 8385283  2018-12     Ystradgynlais & Tawe Uchaf         Theft from the person
# 8385284  2018-12     Ystradgynlais & Tawe Uchaf                 Vehicle crime
# 8385285  2018-12     Ystradgynlais & Tawe Uchaf  Violence and sexual offences
#
#          count
# 0            6
# 1            0
# 2            1
# 3            0
# 4            0
# ...        ...
# 8385281      0
# 8385282      1
# 8385283      0
# 8385284      0
# 8385285     29
#
# [8385286 rows x 4 columns]

# %%
testSetNoCovidCount = countMSOA(testSetNoCovid)
testSetNoCovidCount
# Out:
#            Month                           MSOA                    Crime type  \
# 0        2019-01  Abberley, Holt Heath & Hallow         Anti-social behaviour
# 1        2019-01  Abberley, Holt Heath & Hallow                 Bicycle theft
# 2        2019-01  Abberley, Holt Heath & Hallow                      Burglary
# 3        2019-01  Abberley, Holt Heath & Hallow     Criminal damage and arson
# 4        2019-01  Abberley, Holt Heath & Hallow                         Drugs
# ...          ...                            ...                           ...
# 2325199  2020-12     Ystradgynlais & Tawe Uchaf                       Robbery
# 2325200  2020-12     Ystradgynlais & Tawe Uchaf                   Shoplifting
# 2325201  2020-12     Ystradgynlais & Tawe Uchaf         Theft from the person
# 2325202  2020-12     Ystradgynlais & Tawe Uchaf                 Vehicle crime
# 2325203  2020-12     Ystradgynlais & Tawe Uchaf  Violence and sexual offences
#
#          count
# 0           10
# 1            0
# 2            1
# 3            3
# 4            0
# ...        ...
# 2325199      0
# 2325200      1
# 2325201      0
# 2325202      0
# 2325203     35
#
# [2325204 rows x 4 columns]

# %%
completeSetCount = countMSOA(completeSet)
completeSetCount
# Out:
#             Month                           MSOA  \
# 0         2012-01  Abberley, Holt Heath & Hallow
# 1         2012-01  Abberley, Holt Heath & Hallow
# 2         2012-01  Abberley, Holt Heath & Hallow
# 3         2012-01  Abberley, Holt Heath & Hallow
# 4         2012-01  Abberley, Holt Heath & Hallow
# ...           ...                            ...
# 11645083  2021-10     Ystradgynlais & Tawe Uchaf
# 11645084  2021-10     Ystradgynlais & Tawe Uchaf
# 11645085  2021-10     Ystradgynlais & Tawe Uchaf
# 11645086  2021-10     Ystradgynlais & Tawe Uchaf
# 11645087  2021-10     Ystradgynlais & Tawe Uchaf
#
#                             Crime type  count
# 0                Anti-social behaviour      6
# 1                        Bicycle theft      0
# 2                             Burglary      1
# 3            Criminal damage and arson      0
# 4                                Drugs      0
# ...                                ...    ...
# 11645083                       Robbery      0
# 11645084                   Shoplifting      2
# 11645085         Theft from the person      0
# 11645086                 Vehicle crime      1
# 11645087  Violence and sexual offences     28
#
# [11645088 rows x 4 columns]

# %% [markdown]
# ## Change column names

# %%
# no covid
trainSetCount = trainSetCount.rename(columns={"Month":"Date"})
testSetNoCovidCount = testSetNoCovidCount.rename(columns={"Month":"Date"})
# complete (with covid)
completeSetCount = completeSetCount.rename(columns={"Month":"Date"})

# %% [markdown]
# ## Save as csv

# %%
trainSetCount.to_csv("datasets/train.csv")

# %%
testSetNoCovidCount.to_csv("datasets/test.csv")

# %%
completeSetCount.to_csv("datasets/complete.csv")
